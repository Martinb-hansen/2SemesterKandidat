# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math as math
data1 = pd.read_csv('Megadataset.csv', sep= ',', header=None)
data1.columns = ['sensorSport', 'Potentiometer']

# %%
data1.describe()
# Out:
#        sensorSport  Potentiometer
# count  3195.000000    3195.000000
# mean     24.922048      23.025948
# std      19.106225      21.183058
# min      -1.920831      -0.530504
# 25%       8.968818       0.265252
# 50%      22.431517      15.915119
# 75%      38.177773      41.114058
# max     113.679479      58.620690

# %%
data1.head(5)
# Out:
#    sensorSport  Potentiometer
# 0   113.679479      -0.265252
# 1   111.406133       0.000000
# 2   109.178842      -0.265252
# 3   106.995964      -0.265252
# 4   104.856024      -0.530504

# %%
plt.plot(data1['sensorSport'])
plt.plot(data1['Potentiometer'])
plt.legend(('Sportssensor', 'Potentiometer'))
plt.ylabel("Angle (deg)")
plt.xlabel("Sample count")
plt.title("Variation of motion")
plt.show()
